# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)  # Show full content of each column
pd.set_option('display.max_rows', None)      # Optional: Show all rows
pd.set_option('display.max_columns', None)   # Optional: Show all columns
pd.set_option('display.width', None)

# %%
df = pd.read_csv(r'Flipkart_Reviews - Electronics.csv')
df.head()
# Out:
#          product_id  \
# 0  ACCFZGAQJGYCYDCM
# 1  ACCFZGAQJGYCYDCM
# 2  ACCFZGAQJGYCYDCM
# 3  ACCFZGAQJGYCYDCM
# 4  ACCFZGAQJGYCYDCM
#
#                                                          product_title  \
# 0  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 1  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 2  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 3  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 4  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
#
#    rating            summary  \
# 0       5  Terrific purchase
# 1       5  Terrific purchase
# 2       5             Super!
# 3       5             Super!
# 4       5  Terrific purchase
#
# ...

# %%
df['product_title'].unique()
# Out:
# array(['BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset',
#        'realme Buds Wireless Bluetooth Headset',
#        'OnePlus Bullets Wireless Z Bluetooth Headset',
#        'realme Buds 2 Wired Headset',
#        'OnePlus Bullets Wireless Z Bass Edition Bluetooth Headset',
#        'realme Buds Q Bluetooth Headset',
#        'U&I Titanic Series - Low Price Bluetooth Neckband Bluetooth Headset',
#        'BoAt Airdopes 131 Bluetooth Headset',
#        'BoAt BassHeads 100 Wired Headset'], dtype=object)

# %%
df = df.drop(['product_id', 'summary', 'location', 'date'], axis=1)

# %%
df.head()
# Out:
#                                                          product_title  \
# 0  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 1  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 2  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 3  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
# 4  BoAt Rockerz 235v2 with ASAP charging Version 5.0 Bluetooth Headset
#
#    rating  \
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#
# ...

# %%
df.to_csv('Avaliacao_Produtos.csv', index=False)
